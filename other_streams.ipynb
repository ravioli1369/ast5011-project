# %%
from streams import Streams, obtain_stream_data, obtain_stream_density, plot_density
# Out:
# Initializing galstreams library from master_log...

# %% [markdown]
# # **Analyze Other Streams**
#
# It is increasingly non trivial to obtain the stream stars for streams other than GD-1, so we use the preprocessed stream stars from the [`STREAMFINDER`](https://iopscience.iop.org/article/10.3847/1538-4357/ad382d#apjad382dt1) algorithm.
#
# We also compute the density profile of the stream by counting the number of stars in bins along the phi1 axis. No need to perform background subtraction as we are using basically pure stream stars. Instead, we do a simple median subtraction to see where there are over or under-densities along the stream.
#
# Refer `streams.py` for the helper functions.

# %% [markdown]
# ## **Jhelum**

# %%
jhelum = Streams.JHELUM
jhelum_data = obtain_stream_data(jhelum)
JHELUM_PHI_XLIM = (-10, 27)
JHELUM_PHI_YLIM = (-4, 6)
jhelum_density = obtain_stream_density(
    jhelum_data, PHI_XLIM=JHELUM_PHI_XLIM, binstep=0.5
)
plot_density(
    jhelum,
    jhelum_density,
    jhelum_data,
    PHI_XLIM=JHELUM_PHI_XLIM,
    PHI_YLIM=JHELUM_PHI_YLIM,
)

# %% [markdown]
# ## **Indus**

# %%
indus = Streams.INDUS
indus_data = obtain_stream_data(indus)
INDUS_PHI_XLIM = (-15, 80)
INDUS_PHI_YLIM = (-15, 10)
indus_density = obtain_stream_density(indus_data, PHI_XLIM=INDUS_PHI_XLIM, binstep=0.2)
plot_density(
    indus,
    indus_density,
    indus_data,
    PHI_XLIM=INDUS_PHI_XLIM,
    PHI_YLIM=INDUS_PHI_YLIM,
    perturb1=[13, 23],
    perturb2=[30.5, 50],
)

# %% [markdown]
# ## **NGC6397**

# %%
ngc6397 = Streams.NGC6397
ngc6397_data = obtain_stream_data(ngc6397)
NGC6397_PHI_XLIM = (-7.5, 27)
NGC6397_PHI_YLIM = (-5, 15)
ngc6397_density = obtain_stream_density(
    ngc6397_data, PHI_XLIM=NGC6397_PHI_XLIM, binstep=0.2
)
plot_density(
    ngc6397,
    ngc6397_density,
    ngc6397_data,
    PHI_XLIM=NGC6397_PHI_XLIM,
    PHI_YLIM=NGC6397_PHI_YLIM,
)
ngc6397_density_2 = obtain_stream_density(ngc6397_data, PHI_XLIM=(-4, 27), binstep=0.2)
plot_density(
    ngc6397,
    ngc6397_density_2,
    ngc6397_data,
    PHI_XLIM=(-4, 27),
    PHI_YLIM=NGC6397_PHI_YLIM,
    perturb1=[-3, 2.5],
)

# %% [markdown]
# ## **C-12**

# %%
c12 = Streams.C12
c12_data = obtain_stream_data(c12)
C12_PHI_XLIM = (-15, 15)
C12_PHI_YLIM = (-5, 5)
c12_density = obtain_stream_density(c12_data, PHI_XLIM=C12_PHI_XLIM, binstep=0.1)
plot_density(
    c12,
    c12_density,
    c12_data,
    PHI_XLIM=C12_PHI_XLIM,
    PHI_YLIM=C12_PHI_YLIM,
    perturb1=[1, 3.5],
)

# %% [markdown]
# ## **Orphan**

# %%
orphan = Streams.ORPHAN
orphan_data = obtain_stream_data(orphan)
ORPHAN_PHI_XLIM = (-70, 125)
ORPHAN_PHI_YLIM = (-5, 7.5)
orphan_density = obtain_stream_density(
    orphan_data, PHI_XLIM=ORPHAN_PHI_XLIM, binstep=0.5
)
plot_density(
    orphan,
    orphan_density,
    orphan_data,
    PHI_XLIM=ORPHAN_PHI_XLIM,
    PHI_YLIM=ORPHAN_PHI_YLIM,
    perturb1=[-25, 5],
    perturb2=[34, 47],
)

# %% [markdown]
# ## **Ylgr**

# %%
ylgr = Streams.YLGR
ylgr_data = obtain_stream_data(ylgr)
YLGR_PHI_XLIM = (-25, 30)
YLGR_PHI_YLIM = (-5, 5)
ylgr_density = obtain_stream_density(ylgr_data, PHI_XLIM=YLGR_PHI_XLIM, binstep=0.2)
plot_density(
    ylgr,
    ylgr_density,
    ylgr_data,
    PHI_XLIM=YLGR_PHI_XLIM,
    PHI_YLIM=YLGR_PHI_YLIM,
    perturb1=[1, 4.5],
)
